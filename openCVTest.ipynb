# %%
import cv2
import numpy as np 

# Allows to display images directly in the Jupyter notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Jasper\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['hsv']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
# This is the first webcam connected to the computer
webcam = cv2.VideoCapture(0)

# And this is an image captured with it
retval, image = webcam.read()

# %%
plt.imshow(image)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
figure()
imshow(image_rgb)
# Out:
# Error in callback <function flush_figures at 0x00000230FF7F6E50> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     118         # ignore the tracking, just draw and close all figures
#     119         try:
# --> 120             return show(True)
#     121         except Exception as e:
#     122             # safely show traceback if in IPython, else raise
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      38     try:
#      39         for figure_manager in Gcf.get_all_fig_managers():
# ---> 40             display(
#      41                 figure_manager.canvas.figure,
#      42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
#apply median blur, 15 means it's smoothing image 15x15 pixels
blur = cv2.medianBlur(image_rgb,15)

plt.imshow(blur)

#convert to hsv
hsv = cv2.cvtColor(blur, cv2.COLOR_BGR2HSV)

figure()
plt.imshow(hsv)

#color definition
red_lower = np.array([160,210,230])
red_upper = np.array([180,255,255])

#red color mask (sort of thresholding, actually segmentation)
mask = cv2.inRange(hsv, red_lower, red_upper)
mask.max()
# Out:
# 0

# %%
#color definition
red_lower = np.array([80,0,245])
red_upper = np.array([100,150,255])

#red color mask (sort of thresholding, actually segmentation)
mask = cv2.inRange(hsv, red_lower, red_upper)
mask.max()
plt.imshow(mask)

# %%
x, y, w, h = cv2.boundingRect(mask)
rect1 = cv2.rectangle(image_rgb.copy(),(x,y),(x+w,y+h),(0,255,0),3) # not copying here will throw an error
print("x:{0}, y:{1}, width:{2}, height:{3}".format(x, y, w, h))
plt.imshow(rect1)
plt.show()

print("x ="+ str(x))
print("y ="+ str(y))
print("w =" +str(w))
print("h =" +str(h))
# Out:
# x:335, y:287, width:28, height:27
# x =335
# y =287
# w =28
# h =27

# %%
def getPos():
    retval, image = webcam.read()
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    blur = cv2.medianBlur(image_rgb,15)
    hsv = cv2.cvtColor(blur, cv2.COLOR_BGR2HSV)
    #color definition
    red_lower = np.array([80,0,245])
    red_upper = np.array([100,150,255])
    mask = cv2.inRange(hsv, red_lower, red_upper)
    mask.max()
    x, y, w, h = cv2.boundingRect(mask)
    return x,y,w,h

# %%
x,y,w,h = getPos()

# %%
x
# Out:
# 336

# %%
y
# Out:
# 288
